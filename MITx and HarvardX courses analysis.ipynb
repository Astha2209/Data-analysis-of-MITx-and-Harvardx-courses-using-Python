# %%
# It is convention to import Pandas with the alias pd and Numpy with the alias np
import pandas as pd
import numpy as np

# import warnings library to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Import dataset
df = pd.read_csv('E:/Data Projects/Educational data mining with Python/HMXPC13_DI_v2_5-14-14.csv', parse_dates=['start_time_DI','last_event_DI'])

# %%
# Look at first 5 rows of data
df.head()
# Out:
#                     course_id       userid_DI  registered  viewed  explored  \
# 0  HarvardX/CB22x/2013_Spring  MHxPC130442623           1       0         0
# 1         HarvardX/CS50x/2012  MHxPC130442623           1       1         0
# 2  HarvardX/CB22x/2013_Spring  MHxPC130275857           1       0         0
# 3         HarvardX/CS50x/2012  MHxPC130275857           1       0         0
# 4  HarvardX/ER22x/2013_Spring  MHxPC130275857           1       0         0
#
#    certified final_cc_cname_DI LoE_DI  YoB gender grade start_time_DI  \
# 0          0     United States    NaN  NaN    NaN     0    2012-12-19
# 1          0     United States    NaN  NaN    NaN     0    2012-10-15
# 2          0     United States    NaN  NaN    NaN     0    2013-02-08
# 3          0     United States    NaN  NaN    NaN     0    2012-09-17
# 4          0     United States    NaN  NaN    NaN     0    2012-12-19
#
#   last_event_DI  nevents  ndays_act  nplay_video  nchapters  nforum_posts  \
# ...

# %%
# Look at last 5 rows of data
df.tail()
# Out:
#                       course_id       userid_DI  registered  viewed  explored  \
# 641133   MITx/6.00x/2013_Spring  MHxPC130184108           1       1         0
# 641134   MITx/6.00x/2013_Spring  MHxPC130359782           1       0         0
# 641135  MITx/6.002x/2013_Spring  MHxPC130098513           1       0         0
# 641136   MITx/6.00x/2013_Spring  MHxPC130098513           1       1         0
# 641137   MITx/8.02x/2013_Spring  MHxPC130098513           1       0         0
#
#         certified final_cc_cname_DI      LoE_DI     YoB gender grade  \
# 641133          0            Canada  Bachelor's  1991.0      m   NaN
# 641134          0      Other Europe  Bachelor's  1991.0      f   NaN
# 641135          0     United States   Doctorate  1979.0      m   NaN
# 641136          0     United States   Doctorate  1979.0      m   NaN
# 641137          0     United States   Doctorate  1979.0      m   NaN
#
#        start_time_DI last_event_DI  nevents  ndays_act  nplay_video  \
# ...
